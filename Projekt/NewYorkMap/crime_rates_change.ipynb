# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("crimes1975-2015.csv")

ny = df[df['agency_jurisdiction'].str.contains('NY', regex=False, na=False)]

report_year = ny['report_year'].unique()

locations = {
    'Buffalo, NY': [-78.878738, 42.880230],
    'Nassau County, NY': [-73.59, 40.73],
    'New York City, NY': [-73.935242, 40.730610],
    'Suffolk County, NY': [-72.68, 40.94],
}

ny = ny[[
    'agency_jurisdiction',
    'report_year',
    'crimes_percapita',
    'homicides_percapita',
    'rapes_percapita',
    'assaults_percapita',
    'robberies_percapita'
]]

ny['longitude']=ny.apply(lambda row: locations[row['agency_jurisdiction']][0], axis=1)
ny['lattitude']=ny.apply(lambda row: locations[row['agency_jurisdiction']][1], axis=1)

print(ny.head())
# Out:
#    agency_jurisdiction  report_year  crimes_percapita  homicides_percapita  \
# 8          Buffalo, NY         1975            793.32                14.92
# 39   Nassau County, NY         1975             90.24                 1.64
# 41   New York City, NY         1975           1780.83                22.16
# 61  Suffolk County, NY         1975             79.17                 1.07
# 77         Buffalo, NY         1976            727.12                12.70
#
#     rapes_percapita  assaults_percapita  robberies_percapita  longitude  \
# 8             45.47              178.79               554.14 -78.878738
# 39             3.00               23.26                62.34 -73.590000
# 41            52.08              585.80              1120.78 -73.935242
# 61             7.39               27.10                43.61 -72.680000
# 77            47.52              211.24               455.66 -78.878738
#
#     lattitude
# 8    42.88023
# 39   40.73000
# 41   40.73061
# 61   40.94000
# 77   42.88023

# %%
crimes = px.scatter_geo(data_frame=ny,
                     title='<b>Violent crimes per 100 000 residents</b>',
                     lon='longitude',
                     lat='lattitude',
                     center={'lon': -73.935242, 'lat': 40.730610},
                     animation_frame='report_year',
                     color='agency_jurisdiction',
                     hover_name='agency_jurisdiction',
                     size='crimes_percapita',
                     projection='albers usa')

crimes.show()
# Out:
# <div>
#
#
#             <div id="9d77f76d-5778-44f6-963e-55c28fc1b77c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9d77f76d-5778-44f6-963e-55c28fc1b77c")) {
#                     Plotly.newPlot(
#                         '9d77f76d-5778-44f6-963e-55c28fc1b77c',
#                         [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Buffalo, NY<br>report_year=1975<br>crimes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Buffalo, NY"], "lat": [42.88023], "legendgroup": "Buffalo, NY", "lon": [-78.878738], "marker": {"color": "#636efa", "size": [793.32], "sizemode": "area", "sizeref": 5.9590499999999995}, "name": "Buffalo, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Nassau County, NY<br>report_year=1975<br>crimes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Nassau County, NY"], "lat": [40.73], "legendgroup": "Nassau County, NY", "lon": [-73.59], "marker": {"color": "#EF553B", "size": [90.24], "sizemode": "area", "sizeref": 5.9590499999999995}, "name": "Nassau County, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=New York City, NY<br>report_year=1975<br>crimes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["New York City, NY"], "lat": [40.73061], "legendgroup": "New York City, NY", "lon": [-73.935242], "marker": {"color": "#00cc96", "size": [1780.83], "sizemode": "area", "sizeref": 5.9590499999999995}, "name": "New York City, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Suffolk County, NY<br>report_year=1975<br>crimes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Suffolk County, NY"], "lat": [40.94], "legendgroup": "Suffolk County, NY", "lon": [-72.68], "marker": {"color": "#ab63fa", "size": [79.17], "sizemode": "area", "sizeref": 5.9590499999999995}, "name": "Suffolk County, NY", "showlegend": true, "type": "scattergeo"}],
#                         {"geo": {"center": {"lat": 40.73061, "lon": -73.935242}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "projection": {"type": "albers usa"}}, "legend": {"itemsizing": "constant", "title": {"text": "agency_jurisdiction"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "report_year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1975"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1975", "method": "animate"}, {"args": [["1976"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1976", "method": "animate"}, {"args": [["1977"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1977", "method": "animate"}, {"args": [["1978"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1978", "method": "animate"}, {"args": [["1979"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1979", "method": "animate"}, {"args": [["1980"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1980", "method": "animate"}, {"args": [["1981"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1981", "method": "animate"}, {"args": [["1982"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1982", "method": "animate"}, {"args": [["1983"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1983", "method": "animate"}, {"args": [["1984"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1984", "method": "animate"}, {"args": [["1985"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1985", "method": "animate"}, {"args": [["1986"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1986", "method": "animate"}, {"args": [["1987"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1987", "method": "animate"}, {"args": [["1988"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1988", "method": "animate"}, {"args": [["1989"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1989", "method": "animate"}, {"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromc ...

# %%
homicides = px.scatter_geo(data_frame=ny,
                     title='<b>Homicides per 100 000 residents</b>',
                     lon='longitude',
                     lat='lattitude',
                     center={'lon': -73.935242, 'lat': 40.730610},
                     animation_frame='report_year',
                     color='agency_jurisdiction',
                     hover_name='agency_jurisdiction',
                     size='homicides_percapita',
                     projection='albers usa')

homicides.show()
# Out:
# <div>
#
#
#             <div id="a729b96c-6707-4d6b-a4d6-9a574da66963" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a729b96c-6707-4d6b-a4d6-9a574da66963")) {
#                     Plotly.newPlot(
#                         'a729b96c-6707-4d6b-a4d6-9a574da66963',
#                         [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Buffalo, NY<br>report_year=1975<br>homicides_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Buffalo, NY"], "lat": [42.88023], "legendgroup": "Buffalo, NY", "lon": [-78.878738], "marker": {"color": "#636efa", "size": [14.92], "sizemode": "area", "sizeref": 0.07665}, "name": "Buffalo, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Nassau County, NY<br>report_year=1975<br>homicides_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Nassau County, NY"], "lat": [40.73], "legendgroup": "Nassau County, NY", "lon": [-73.59], "marker": {"color": "#EF553B", "size": [1.64], "sizemode": "area", "sizeref": 0.07665}, "name": "Nassau County, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=New York City, NY<br>report_year=1975<br>homicides_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["New York City, NY"], "lat": [40.73061], "legendgroup": "New York City, NY", "lon": [-73.935242], "marker": {"color": "#00cc96", "size": [22.16], "sizemode": "area", "sizeref": 0.07665}, "name": "New York City, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Suffolk County, NY<br>report_year=1975<br>homicides_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Suffolk County, NY"], "lat": [40.94], "legendgroup": "Suffolk County, NY", "lon": [-72.68], "marker": {"color": "#ab63fa", "size": [1.07], "sizemode": "area", "sizeref": 0.07665}, "name": "Suffolk County, NY", "showlegend": true, "type": "scattergeo"}],
#                         {"geo": {"center": {"lat": 40.73061, "lon": -73.935242}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "projection": {"type": "albers usa"}}, "legend": {"itemsizing": "constant", "title": {"text": "agency_jurisdiction"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "report_year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1975"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1975", "method": "animate"}, {"args": [["1976"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1976", "method": "animate"}, {"args": [["1977"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1977", "method": "animate"}, {"args": [["1978"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1978", "method": "animate"}, {"args": [["1979"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1979", "method": "animate"}, {"args": [["1980"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1980", "method": "animate"}, {"args": [["1981"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1981", "method": "animate"}, {"args": [["1982"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1982", "method": "animate"}, {"args": [["1983"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1983", "method": "animate"}, {"args": [["1984"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1984", "method": "animate"}, {"args": [["1985"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1985", "method": "animate"}, {"args": [["1986"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1986", "method": "animate"}, {"args": [["1987"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1987", "method": "animate"}, {"args": [["1988"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1988", "method": "animate"}, {"args": [["1989"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1989", "method": "animate"}, {"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromc ...

# %%
rapes = px.scatter_geo(data_frame=ny,
                     title='<b>Rapes per 100 000 residents</b>',
                     lon='longitude',
                     lat='lattitude',
                     center={'lon': -73.935242, 'lat': 40.730610},
                     animation_frame='report_year',
                     color='agency_jurisdiction',
                     hover_name='agency_jurisdiction',
                     size='rapes_percapita',
                     projection='albers usa')

rapes.show()
# Out:
# <div>
#
#
#             <div id="d46b7299-a3d8-4fa2-ae26-f4005a77b9be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d46b7299-a3d8-4fa2-ae26-f4005a77b9be")) {
#                     Plotly.newPlot(
#                         'd46b7299-a3d8-4fa2-ae26-f4005a77b9be',
#                         [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Buffalo, NY<br>report_year=1975<br>rapes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Buffalo, NY"], "lat": [42.88023], "legendgroup": "Buffalo, NY", "lon": [-78.878738], "marker": {"color": "#636efa", "size": [45.47], "sizemode": "area", "sizeref": 0.270475}, "name": "Buffalo, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Nassau County, NY<br>report_year=1975<br>rapes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Nassau County, NY"], "lat": [40.73], "legendgroup": "Nassau County, NY", "lon": [-73.59], "marker": {"color": "#EF553B", "size": [3.0], "sizemode": "area", "sizeref": 0.270475}, "name": "Nassau County, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=New York City, NY<br>report_year=1975<br>rapes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["New York City, NY"], "lat": [40.73061], "legendgroup": "New York City, NY", "lon": [-73.935242], "marker": {"color": "#00cc96", "size": [52.08], "sizemode": "area", "sizeref": 0.270475}, "name": "New York City, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Suffolk County, NY<br>report_year=1975<br>rapes_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Suffolk County, NY"], "lat": [40.94], "legendgroup": "Suffolk County, NY", "lon": [-72.68], "marker": {"color": "#ab63fa", "size": [7.39], "sizemode": "area", "sizeref": 0.270475}, "name": "Suffolk County, NY", "showlegend": true, "type": "scattergeo"}],
#                         {"geo": {"center": {"lat": 40.73061, "lon": -73.935242}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "projection": {"type": "albers usa"}}, "legend": {"itemsizing": "constant", "title": {"text": "agency_jurisdiction"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "report_year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1975"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1975", "method": "animate"}, {"args": [["1976"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1976", "method": "animate"}, {"args": [["1977"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1977", "method": "animate"}, {"args": [["1978"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1978", "method": "animate"}, {"args": [["1979"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1979", "method": "animate"}, {"args": [["1980"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1980", "method": "animate"}, {"args": [["1981"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1981", "method": "animate"}, {"args": [["1982"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1982", "method": "animate"}, {"args": [["1983"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1983", "method": "animate"}, {"args": [["1984"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1984", "method": "animate"}, {"args": [["1985"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1985", "method": "animate"}, {"args": [["1986"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1986", "method": "animate"}, {"args": [["1987"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1987", "method": "animate"}, {"args": [["1988"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1988", "method": "animate"}, {"args": [["1989"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1989", "method": "animate"}, {"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromc ...

# %%
assaults = px.scatter_geo(data_frame=ny,
                     title='<b>Assaults per 100 000 residents</b>',
                     lon='longitude',
                     lat='lattitude',
                     center={'lon': -73.935242, 'lat': 40.730610},
                     animation_frame='report_year',
                     color='agency_jurisdiction',
                     hover_name='agency_jurisdiction',
                     size='assaults_percapita',
                     projection='albers usa')

assaults.show()
# Out:
# <div>
#
#
#             <div id="49b6dda1-2ce1-45ea-b352-cd8723f74898" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49b6dda1-2ce1-45ea-b352-cd8723f74898")) {
#                     Plotly.newPlot(
#                         '49b6dda1-2ce1-45ea-b352-cd8723f74898',
#                         [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Buffalo, NY<br>report_year=1975<br>assaults_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Buffalo, NY"], "lat": [42.88023], "legendgroup": "Buffalo, NY", "lon": [-78.878738], "marker": {"color": "#636efa", "size": [178.79], "sizemode": "area", "sizeref": 2.54005}, "name": "Buffalo, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Nassau County, NY<br>report_year=1975<br>assaults_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Nassau County, NY"], "lat": [40.73], "legendgroup": "Nassau County, NY", "lon": [-73.59], "marker": {"color": "#EF553B", "size": [23.26], "sizemode": "area", "sizeref": 2.54005}, "name": "Nassau County, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=New York City, NY<br>report_year=1975<br>assaults_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["New York City, NY"], "lat": [40.73061], "legendgroup": "New York City, NY", "lon": [-73.935242], "marker": {"color": "#00cc96", "size": [585.8], "sizemode": "area", "sizeref": 2.54005}, "name": "New York City, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Suffolk County, NY<br>report_year=1975<br>assaults_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Suffolk County, NY"], "lat": [40.94], "legendgroup": "Suffolk County, NY", "lon": [-72.68], "marker": {"color": "#ab63fa", "size": [27.1], "sizemode": "area", "sizeref": 2.54005}, "name": "Suffolk County, NY", "showlegend": true, "type": "scattergeo"}],
#                         {"geo": {"center": {"lat": 40.73061, "lon": -73.935242}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "projection": {"type": "albers usa"}}, "legend": {"itemsizing": "constant", "title": {"text": "agency_jurisdiction"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "report_year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1975"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1975", "method": "animate"}, {"args": [["1976"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1976", "method": "animate"}, {"args": [["1977"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1977", "method": "animate"}, {"args": [["1978"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1978", "method": "animate"}, {"args": [["1979"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1979", "method": "animate"}, {"args": [["1980"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1980", "method": "animate"}, {"args": [["1981"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1981", "method": "animate"}, {"args": [["1982"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1982", "method": "animate"}, {"args": [["1983"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1983", "method": "animate"}, {"args": [["1984"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1984", "method": "animate"}, {"args": [["1985"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1985", "method": "animate"}, {"args": [["1986"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1986", "method": "animate"}, {"args": [["1987"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1987", "method": "animate"}, {"args": [["1988"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1988", "method": "animate"}, {"args": [["1989"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1989", "method": "animate"}, {"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromc ...

# %%
robberies = px.scatter_geo(data_frame=ny,
                     title='<b>Robberies per 100 000 residents</b>',
                     lon='longitude',
                     lat='lattitude',
                     center={'lon': -73.935242, 'lat': 40.730610},
                     animation_frame='report_year',
                     color='agency_jurisdiction',
                     hover_name='agency_jurisdiction',
                     size='robberies_percapita',
                     projection='albers usa')

robberies.show()
# Out:
# <div>
#
#
#             <div id="e1cb1254-c1af-4381-92b0-5d9674c98de2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1cb1254-c1af-4381-92b0-5d9674c98de2")) {
#                     Plotly.newPlot(
#                         'e1cb1254-c1af-4381-92b0-5d9674c98de2',
#                         [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Buffalo, NY<br>report_year=1975<br>robberies_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Buffalo, NY"], "lat": [42.88023], "legendgroup": "Buffalo, NY", "lon": [-78.878738], "marker": {"color": "#636efa", "size": [554.14], "sizemode": "area", "sizeref": 3.80015}, "name": "Buffalo, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Nassau County, NY<br>report_year=1975<br>robberies_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Nassau County, NY"], "lat": [40.73], "legendgroup": "Nassau County, NY", "lon": [-73.59], "marker": {"color": "#EF553B", "size": [62.34], "sizemode": "area", "sizeref": 3.80015}, "name": "Nassau County, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=New York City, NY<br>report_year=1975<br>robberies_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["New York City, NY"], "lat": [40.73061], "legendgroup": "New York City, NY", "lon": [-73.935242], "marker": {"color": "#00cc96", "size": [1120.78], "sizemode": "area", "sizeref": 3.80015}, "name": "New York City, NY", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>agency_jurisdiction=Suffolk County, NY<br>report_year=1975<br>robberies_percapita=%{marker.size}<br>lattitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Suffolk County, NY"], "lat": [40.94], "legendgroup": "Suffolk County, NY", "lon": [-72.68], "marker": {"color": "#ab63fa", "size": [43.61], "sizemode": "area", "sizeref": 3.80015}, "name": "Suffolk County, NY", "showlegend": true, "type": "scattergeo"}],
#                         {"geo": {"center": {"lat": 40.73061, "lon": -73.935242}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "projection": {"type": "albers usa"}}, "legend": {"itemsizing": "constant", "title": {"text": "agency_jurisdiction"}, "tracegroupgap": 0}, "sliders": [{"active": 0, "currentvalue": {"prefix": "report_year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1975"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1975", "method": "animate"}, {"args": [["1976"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1976", "method": "animate"}, {"args": [["1977"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1977", "method": "animate"}, {"args": [["1978"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1978", "method": "animate"}, {"args": [["1979"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1979", "method": "animate"}, {"args": [["1980"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1980", "method": "animate"}, {"args": [["1981"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1981", "method": "animate"}, {"args": [["1982"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1982", "method": "animate"}, {"args": [["1983"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1983", "method": "animate"}, {"args": [["1984"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1984", "method": "animate"}, {"args": [["1985"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1985", "method": "animate"}, {"args": [["1986"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1986", "method": "animate"}, {"args": [["1987"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1987", "method": "animate"}, {"args": [["1988"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1988", "method": "animate"}, {"args": [["1989"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1989", "method": "animate"}, {"args": [["1990"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1990", "method": "animate"}, {"args": [["1991"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1991", "method": "animate"}, {"args": [["1992"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "1992", "method": "animate"}, {"args": [["1993"], {"frame": {"duration": 0, "redraw": true}, "fromc ...
